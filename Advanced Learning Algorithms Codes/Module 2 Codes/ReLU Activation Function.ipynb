# %%
# Load the Libraries

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.activations import linear, relu, sigmoid
# Out:
# 2023-06-05 13:22:46.190390: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## ReLU Activation Function
# Rectified Linear Unit (ReLU):
# $$ a = max(0,z) \quad\quad\text {# ReLU Function} $$

# %% [markdown]
# ![Screenshot%202023-06-05%20at%2013.38.16.png](attachment:Screenshot%202023-06-05%20at%2013.38.16.png)

# %% [markdown]
# ![Screenshot%202023-06-05%20at%2013.38.45.png](attachment:Screenshot%202023-06-05%20at%2013.38.45.png)

# %% [markdown]
# ![Screenshot%202023-06-05%20at%2013.39.00.png](attachment:Screenshot%202023-06-05%20at%2013.39.00.png)

# %% [markdown]
# ![Screenshot%202023-06-05%20at%2013.39.13.png](attachment:Screenshot%202023-06-05%20at%2013.39.13.png)
